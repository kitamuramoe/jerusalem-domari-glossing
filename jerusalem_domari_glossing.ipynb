# %% [markdown]
# <a href="https://colab.research.google.com/github/kitamuramoe/aleppo-domari-glossing/blob/main/aleppo_domari_glossing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1a: Morphological Segmentation (Preprocessing + Word Replacement)
#
# Morphological boundaries are inserted into words in two steps:
#
# 1. **Preprocessing**:
#    This step adds a space or hyphen (`-`) after specific punctuation marks or endings.
#    For example, the clitic `e'` (meaning ‘NEG’) is separated from the preceding word,
#    as it typically follows an inflected phrase and should be treated as an independent morpheme.
#    This prevents segmentation errors in the next step.
#
# 2. **Word replacement using a segmentation list**:
#    Words are checked for known endings and replaced with their segmented equivalents.
#    These replacements are defined in a text file (`morpheme_boundary_dic.txt`)
#    where each line lists an original word ending and its segmented version (with hyphens).
#    Longer patterns are applied first to avoid partial matches overriding full ones.
#
#    **Whole-word replacement**:
#    The segmentation algorithm may over-apply suffix replacement rules (e.g. `ḍom` → `ḍ-o-m`, `šari` → `-š-ar-i`).
#    To prevent this, the script first checks each word against a whole-word replacement dictionary and applies the specified correction before segmentation.
#
# Lines starting with a quotation mark (e.g., translations) are skipped and preserved as-is.
#
# Example :
# - `kuryaka.` → `kur -y-a-ka .` (house -F-OBL.F-DAT .)
#
# ## Input Format
#
# The input file should consist of unsegmented Jerusalem Domari sentences,
# each followed by an English translation enclosed in quotation marks (e.g., `'`).
# Each sentence pair should appear on two consecutive lines, followed by a blank line to separate entries.
# Lines starting with a quotation mark will be preserved throughout all processing steps.

# %%
def preprocess_morpheme_boundaries(input_file, output_file):
    # Define a mapping of patterns to replace
    replacements = {
        ',' : ' ,',
        '.' : ' .',
        '!' : ' !',
        '?' : ' ?',
        ':' : ' :',
        ';' : ' ;',
        '!?' : ' !?',
        "e'" : " e'",
    }

    # Read the input file
    with open(input_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Process each line
    updated_lines = []
    for line in lines:
      # Skip lines that begin with a quotation mark
        if line.startswith("'"):
            updated_lines.append(line.strip())
            continue
        # Split the line into words and process each word
        words = line.strip().split()
        updated_words = []
        for word in words:
            # Check if the word ends with any pattern in the replacements dictionary
            for original, replacement in replacements.items():
                if word.endswith(original):
                    word = word[:len(word) - len(original)] + replacement
                    break  # Stop checking other patterns once a match is found
            updated_words.append(word)
        # Reconstruct the line with updated words
        updated_lines.append(' '.join(updated_words))

    # Write the updated content to the output file
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write('\n'.join(updated_lines))

    print(f"Processed file saved as {output_file}")

# Process the uploaded file
input_file = "matras_abu_hasan.txt" # Change this to your actual input file 
output_file = "output_texts/morpheme_boundary_base.txt"
preprocess_morpheme_boundaries(input_file, output_file)
# Out:
# Processed file saved as output_texts/morpheme_boundary_base.txt

# %%
def load_replacements(replacements_file):
    """Load replacements from a text file into a dictionary."""
    replacements = {}

    with open(replacements_file, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.rstrip('\n')

            if line and '\t' in line:
                original, replacement = line.split('\t', 1)
                replacements[original] = replacement
                
    # Sort replacements by length (longest first) to prevent partial matches interfering
    sorted_replacements = dict(
        sorted(replacements.items(), key=lambda x: len(x[0]), reverse=True)
    )

    return sorted_replacements


def add_morpheme_boundaries(input_file, output_file, suffix_replacements_file, whole_word_replacements_file):
    """Process the input file using whole-word and suffix replacement dictionaries."""

    # the whole-word replacement dictionary and the suffix replacement dictionary
    whole_word_replacements = load_replacements(whole_word_replacements_file)
    suffix_replacements = load_replacements(suffix_replacements_file)

    with open(input_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    updated_lines = []

    for line in lines:
        if line.startswith(("'", '"')):
            updated_lines.append(line.strip())
            continue

        words = line.strip().split()
        updated_words = []

        for word in words:

            # 1. First, check the whole-word replacement dictionary
            if word in whole_word_replacements:
                word = whole_word_replacements[word]

            # 2. If not found in the whole-word dictionary, check the suffix replacement dictionary
            else:
                for original, replacement in suffix_replacements.items():
                    if word.endswith(original):
                        word = word[:len(word) - len(original)] + replacement
                        break

            updated_words.append(word)

        updated_lines.append(' '.join(updated_words))

    with open(output_file, 'w', encoding='utf-8') as file:
        file.write('\n'.join(updated_lines))

    print(f"Processed file saved as {output_file}")


# Define file paths
whole_word_replacements_file = "dictionaries/skip_morpheme_boundary_dic.txt"
suffix_replacements_file = "dictionaries/morpheme_boundary_dic.txt"

input_file = "output_texts/morpheme_boundary_base.txt"
output_file = "output_texts/morpheme_boundary_processed.txt"

# Run the function
add_morpheme_boundaries(
    input_file,
    output_file,
    suffix_replacements_file,
    whole_word_replacements_file
)
# Out:
# Processed file saved as output_texts/morpheme_boundary_processed.txt

# %% [markdown]
# ## Step 1b: Correcting Over-segmentation
#
# This step applies additional adjustments to morpheme segmentation using a list of replacement patterns.
# It is used to correct cases where automatic segmentation may have over-applied boundary rules.
#
# The script reads a replacement dictionary (`adjust_morpheme_boundary.txt`),
# where each line lists an original word and its adjusted version.
#
# Replacements are applied from longest to shortest match to avoid partial overlap issues.
#
# Example:
# - `n-as-r-a` (n- + -as-r-a ‘-2PL-2SG-REM’) → `nas-r-a` (‘escape-PFV-3SG.M’)

# %%
def load_replacements(replacements_file):
    """Load gloss replacements from a text file into a dictionary, sorted by length (longest first)."""
    replacements = {}
    with open(replacements_file, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if line and '\t' in line:  # Ensure valid entries
                original, replacement = line.split('\t', 1)
                replacements[original] = replacement

    # Sort replacements by length (longest first) to prevent partial matches interfering
    sorted_replacements = dict(sorted(replacements.items(), key=lambda x: len(x[0]), reverse=True))
    return sorted_replacements

def adjust_morpheme_boundaries(input_file, output_file, replacements):
    """Read a text file, replace occurrences based on a dictionary, and save the result."""
    # Read content
    with open(input_file, "r", encoding="utf-8") as file:
        content = file.read()

    # Apply replacements
    for old, new in replacements.items():
        content = content.replace(old, new)

    # Write the updated content to the output file
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(content)

    print(f"Processed file saved as {output_file}")

# Define file paths
replacements_file = "dictionaries/adjust_morpheme_boundary.txt"
input_file = "output_texts/morpheme_boundary_processed.txt"  # Change this to your actual input file
output_file = "output_texts/morpheme_boundary_adjusted.txt"

# Load replacements and process the file
replacements = load_replacements(replacements_file)
adjust_morpheme_boundaries(input_file, output_file, replacements)
# Out:
# Processed file saved as output_texts/morpheme_boundary_adjusted.txt

# %% [markdown]
# ## Step 2: Splitting into One Word Per Line
#
# This step converts each sentence into a list of individual words, with one word per line.
#
# This step is applied to segmented text.
# Lines that start with a quotation mark (e.g., translations) are preserved as they are.
#
# After this step, **download the output file and manually check whether each word is correctly segmented** into morphemes.
# If over-segmentation or incorrect boundaries are found, correct them manually before proceeding.

# %%
input_file = 'output_texts/morpheme_boundary_adjusted.txt'
output_file = 'output_texts/processed_words.txt'

# Open the input and output files
with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
    for line in infile:
        # Strip leading/trailing whitespace
        line = line.strip()

        # Skip processing if the line starts with a quotation mark
        if not line or line.startswith(("'", '"')):
            outfile.write(line + '\n')
        else:
            # Split the line into words and write each word on a new line
            words = line.split()
            for word in words:
                outfile.write(word + '\n')

print(f"Processed text has been saved to '{output_file}'.")
# Out:
# Processed text has been saved to 'output_texts/processed_words.txt'.

# %% [markdown]
# ## Step 3: Interlinear Glossing
#
# In this step, each word is matched against a predefined gloss dictionary and assigned a gloss if available.
#
# The script reads a dictionary file (`dictionary_jerusalem_domari.txt`) from the `dictionaries/` folder.
# Each line in the file lists a word and its corresponding gloss, separated by a tab character.
#
# The script then reads the list of segmented words from `output_texts/processed_words.txt`,
# and for each word:
# - If a gloss is found, the word and its gloss are written side by side (tab-separated).
# - If no gloss is found, the word is written alone to indicate a missing entry.
# - If the token is a punctuation mark (e.g., !, ?, ,, .), a double asterisk (`**`) is output instead of a gloss. These will be removed in the next step.
#
# Example:
# - `ḍom` → `ḍom	Dom/people`
#
#
# The glossed output is saved as `output_texts/output_texts_glossed.txt`.

# %%
dictfile = open('dictionaries/dictionary_jerusalem_domari.txt', 'r', encoding='utf-8')
dic = {}
for line in dictfile:
    # Strip trailing whitespace and split the line by tabs
    line = line.rstrip().split('\t')
    # Ensure there are at least two elements (key and value)
    if len(line) >= 2:
        key = line[0]
        value = line[1]
        # Add the key-value pair to the dictionary
        dic[key] = value
dictfile.close()
print(dic)
# Out:
# {'-a': '-M', '-ī': '-F', '-i': '-F/PRED.SG', '-e': '-PL', '-an': '-1PL', '-iya': '-F', '-at': '-3SG.F', '-ni': '-PRED.PL', '-ēk': '-PRED.SG.M/2SG', '-ēk-i': '-PRED.SG.M-PRED', '-m-ēk': '-LOC-PRED.SG.M', '-ik': '-PRED.SG.F', '-ik-i': '-PRED.SG.F-PRED', '-ēn-i': '-PRED.PL-PRED', '-ēn': '-PRED.PL', '-ak': '-INDEF', '-ak-i': '-INDEF-PRED', '-as': '-OBL.M/2PL', '-y-a': '-F-OBL.F', "-e'": '-NEG', '-ta': '-DAT', '-as-ta': '-OBL.M-DAT', '-y-a-ta': '-OBL.F-DAT', '-an-ta': '-OBL.PL-DAT', '-y-an-ta': '-F-OBL.PL-DAT', '-im-ta': '-1SG.OBL-DAT', '-ir-ta': '-2SG.OBL-DAT', '-is-ta': '-3SG.OBL-DAT', '-o-m-ta': '-SG-1SG.OBL-DAT', '-o-r-ta': '-SG-2SG.OBL-DAT', '-o-s-ta': '-SG-3SG.OBL-DAT', '-ē-m-ta': '-PL-1SG.OBL-DAT', '-ē-r-ta': '-PL-2SG.OBL-DAT', '-ē-s-ta': '-PL-3SG.OBL-DAT', '-o-man-ta': '-SG-1PL.OBL-DAT', '-o-ran-ta': '-SG-2PL.OBL-DAT', '-o-san-ta': '-SG-3PL.OBL-DAT', '-ē-man-ta': '-PL-1PL.OBL-DAT', '-ē-ran-ta': '-PL-2PL.OBL-DAT', '-ē-san-ta': '-PL-3PL.OBL-DAT', '-ki': '-ABL', '-as-ki': '-OBL.M-ABL', '-y-a-ki': '-OBL.F-ABL', '-an-ki': '-OBL.PL-ABL', '-y-an-ki': '-F-OBL.PL-ABL', '-im-ki': '-1SG.OBL-ABL', '-ir-ki': '-2SG.OBL-ABL', '-is-ki': '-3SG.OBL-ABL', '-o-m-ki': '-SG-1SG.OBL-ABL', '-o-r-ki': '-SG-2SG.OBL-ABL', '-o-s-ki': '-SG-3SG.OBL-ABL', '-ē-m-ki': '-PL-1SG.OBL-ABL', '-ē-r-ki': '-PL-2SG.OBL-ABL', '-ē-s-ki': '-PL-3SG.OBL-ABL', '-o-man-ki': '-SG-1PL.OBL-ABL', '-o-ran-ki': '-SG-2PL.OBL-ABL', '-o-san-ki': '-SG-3PL.OBL-ABL', '-ē-man-ki': '-PL-1PL.OBL-ABL', '-ē-ran-ki': '-PL-2PL.OBL-ABL', '-ē-san-ki': '-PL-3PL.OBL-ABL', '-ma': '-LOC', '-mà': '-LOC', '-as-ma': '-OBL.M-LOC', '-y-a-ma': '-OBL.F-LOC', '-an-ma': '-OBL.PL-LOC', '-y-an-ma': '-F-OBL.PL-LOC', '-im-ma': '-1SG.OBL-LOC', '-ir-ma': '-2SG.OBL-LOC', '-is-ma': '-3SG.OBL-LOC', '-o-m-ma': '-SG-1SG.OBL-LOC', '-o-r-ma': '-SG-2SG.OBL-LOC', '-o-s-ma': '-SG-3SG.OBL-LOC', '-ē-m-ma': '-PL-1SG.OBL-LOC', '-ē-r-ma': '-PL-2SG.OBL-LOC', '-ē-s-ma': '-PL-3SG.OBL-LOC', '-o-man-ma': '-SG-1PL.OBL-LOC', '-o-ran-ma': '-SG-2PL.OBL-LOC', '-o-san-ma': '-SG-3PL.OBL-LOC', '-ē-man-ma': '-PL-1PL.OBL-LOC', '-ē-ran-ma': '-PL-2PL.OBL-LOC', '-ē-san-ma': '-PL-3PL.OBL-LOC', '-ka': '-DAT', '-as-ka': '-OBL.M-DAT', '-y-a-ka': '-F-OBL.F-DAT', '-an-ka': '-OBL.PL-DAT', '-y-an-ka': '-F-OBL.PL-DAT', '-im-ka': '-1SG.OBL-DAT', '-ir-ka': '-2SG.OBL-DAT', '-is-ka': '-3SG.OBL-DAT', '-o-m-ka': '-SG-1SG.OBL-DAT', '-o-r-ka': '-SG-2SG.OBL-DAT', '-o-s-ka': '-SG-3SG.OBL-DAT', '-ē-m-ka': '-PL-1SG.OBL-DAT', '-ē-r-ka': '-PL-2SG.OBL-DAT', '-ē-s-ka': '-PL-3SG.OBL-DAT', '-o-man-ka': '-SG-1PL.OBL-DAT', '-o-ran-ka': '-SG-2PL.OBL-DAT', '-o-san-ka': '-SG-3PL.OBL-DAT', '-ē-man-ka': '-PL-1PL.OBL-DAT', '-ē-ran-ka': '-PL-2PL.OBL-DAT', '-ē-san-ka': '-PL-3PL.OBL-DAT', '-ke': '-BEN', '-as-ke': '-OBL.M-BEN', '-y-a-ke': '-OBL.F-BEN', '-an-ke': '-OBL.PL-BEN', '-y-an-ke': '-F-OBL.PL-BEN', '-im-ke': '-1SG.OBL-BEN', '-ir-ke': '-2SG.OBL-BEN', '-is-ke': '-3SG.OBL-BEN', '-o-m-ke': '-SG-1SG.OBL-BEN', '-o-r-ke': '-SG-2SG.OBL-BEN', '-o-s-ke': '-SG-3SG.OBL-BEN', '-ē-m-ke': '-PL-1SG.OBL-BEN', '-ē-r-ke': '-PL-2SG.OBL-BEN', '-ē-s-ke': '-PL-3SG.OBL-BEN', '-o-man-ke': '-SG-1PL.OBL-BEN', '-o-ran-ke': '-SG-2PL.OBL-BEN', '-o-san-ke': '-SG-3PL.OBL-BEN', '-ē-man-ke': '-PL-1PL.OBL-BEN', '-ē-ran-ke': '-PL-2PL.OBL-BEN', '-ē-san-ke': '-PL-3PL.OBL-BEN', '-as-kara': '-OBL.M-BEN', '-y-a-kara': '-OBL.F-BEN', '-an-kara': '-OBL.PL-BEN', '-y-an-kara': '-F-OBL.PL-BEN', '-im-kara': '-1SG.OBL-BEN', '-ir-kara': '-2SG.OBL-BEN', '-is-kara': '-3SG.OBL-BEN', '-o-m-kara': '-SG-1SG.OBL-BEN', '-o-r-kara': '-SG-2SG.OBL-BEN', '-o-s-kara': '-SG-3SG.OBL-BEN', '-ē-m-kara': '-PL-1SG.OBL-BEN', '-ē-r-kara': '-PL-2SG.OBL-BEN', '-ē-s-kara': '-PL-3SG.OBL-BEN', '-o-man-kara': '-SG-1PL.OBL-BEN', '-o-ran-kara': '-SG-2PL.OBL-BEN', '-o-san-kara': '-SG-3PL.OBL-BEN', '-ē-man-kara': '-PL-1PL.OBL-BEN', '-ē-ran-kara': '-PL-2PL.OBL-BEN', '-ē-san-kara': '-PL-3PL.OBL-BEN', 'ab-om-ke': 'for-1SG-BEN', 'ab-or-ke': 'for-2SG-BEN', 'ab-os-ke': 'for-3SG-BEN', 'ab-us-ke': 'for-3SG-BEN', 'ab-man-ke': 'for-1PL-BEN', 'ab-ran-ke': 'for-2PL- ...

# %%
txtfile = open('output_texts/processed_words.txt', encoding='utf-8')
words = []
for i in txtfile:
  i = i.rstrip()
  words.append(i)

output_file = 'output_texts/glossed.txt'

# Open the output file for writing
with open(output_file, 'w', encoding='utf-8') as out_f:
    # Iterate through each word in the list
    for w in words:
        if w in dic:
            # If the word is in the dictionary, write the word and its value
            out_f.write(f"{w}\t{dic[w]}\n")
        else:
            # If the word is not in the dictionary, write the word alone
            out_f.write(f"{w}\n")

# Print to verify the output file content (optional)
with open(output_file, 'r', encoding='utf-8') as out_f:
    print(out_f.read())
# Out:
# kān	who/which/was
# ikak	one.F
# -i	-F/PRED.SG
# ṭāṭ	Arab/villager
# -i	-F/PRED.SG
# .
# "There was a fellah"
#
# kān	who/which/was
# ašti	there.is
# nkī-s	LOC-3SG
# di	two
# gorw	cow
# -e	-PL
# .
# "he had two oxen."
#
# kān	who/which/was
# ḥruṭ
# -kara	-BEN
# wāšī-san	SOC-3PL
# "He was ploughing on them."
#
# gorw	cow
# -ak	-INDEF
# ikak	one.F
# nas-	escape-
# -r-i	-PFV-3SG.F
# .
# "An ox arose from there , and got free."
#
# ṭāṭ	Arab/villager
# man-	leave-
# -d-a	-PFV-3SG.M
# gorw	cow
# -y-a	-F-OBL.F
# ū	and
# ga-r-a	go-PFV-3SG.M
# kur	house
# -y-a-ka	-F-OBL.F-DAT
# "The fellah left him (the ox) , went to his house."
#
# sabaḥtan	in.the.morning
# t-a	give.PFV-3SG.M
# lah-	see-
# -am	-1SG
# tōr-as
# bidd-ī	want-1SG
# mar-	kill-
# -am-is	-1SG-3SG
# ihi	this.F
# šar
# -y-a-ma	-OBL.F-LOC
# "He said "In the morning if I see thee , oh thou ox , in this place , I will slay thee with this knife.""
#
# t-ōr	give.PFV-2SG
# lah-	see-
# -ed-a	-PFV-3SG.M
# ḥašīšī	grass
# dirg-	long
# -ēk	-PRED.SG.M/2SG
# ū	and
# ga-r-a	go-PFV-3SG.M
# "The ox betook himself and went . He saw long grass."
#
# man-	leave-
# -ī-r-a	-VITR-PFV-3SG.M
# hnon	there
# qēy-	eat-
# -r-a	-PFV-3SG.M
# giš	all
# ḥašīšī	grass
# "he stayed , ate of it."
#
# ē-r-a	come-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# abu	Abu
# ḥasan	Hasan
# ,
# "There came to him Abu Ḥasan"
#
# saʕlab
# -i	-F/PRED.SG
# .
# "Abu Ḥasan betook himself"
#
# abu	Abu
# ḥasan	Hasan
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# "he (Abu Ḥasan) said to him:"
#
# kē	what
# ka-
# -r-ēk	-PFV-PRES.3SG.M
# hnēna	here
# -y-a	-F-OBL.F
# t-ōr	give.PFV-2SG
# ,
# "Why do you stay here?"
#
# aha	this.m
# dary-
# -o-s-i	-2SG-3SG
# nimir	Nimr
# -ki	-ABL
# .
# "This is a panther's place,"
#
# t-a	give.PFV-3SG.M
# aw-	come-
# -ar	-3SG
# nim
# -is	-3SG.OBL
# bag-	break-
# -ar-i	-3SG-PRES
# xar	bone
# -ē-r	-PL-2SG
# "the hour she comes she will strike and break thy ribs""
#
# abu	Abu
# ḥasan	Hasan
# ga-r-a	go-PFV-3SG.M
# nimir	Nimr
# -ke	-BEN
# "Abu Ḥasan betook himself and went to the panther."
#
# ē-r-a	come-PFV-3SG.M
# t-ōr	give.PFV-2SG
# ū	and
# qē-	eat-
# -r-a	-PFV-3SG.M
# giš	all
# ḥašīš	grass
# -ē-r	-PL-2SG
# .
# "He said "This ox has eaten in thy grass""
#
# abu	Abu
# ḥasan	Hasan
# šar-	hide-
# -ī-r-a	-VITR-PFV-3SG.M
# .
# "Abu Ḥasan was hidden"
#
# nimir	Nimr
# ē-r-a	come-PFV-3SG.M
# ,
# "the panther came to him."
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# tōr-as-ke
# kēkē	how/why
# man-	leave-
# -ī-r-or	-VITR-PFV-2SG
# hnēna	here
# ḥašīš	grass
# -ma	-LOC
# ?
# "he said "Why , oh though Ox , dost thou stay in this spring-grass""
#
# ṣāḥb-
# -om	-1SG
# kull	every
# ḥīn
# kam-	work
# -k-ar-i	-VTR-3SG-PRES
# ʕankī-m	about-1SG
# ū	and
# ama	I
# tʕiba-
# -h-r-om	-VITR-PFV-1SG
# .
# "My master ploughs on me , "
#
# ū	and
# ama	I
# bkara-	hungry-
# -h-r-om	-VITR-PFV-1SG
# .
# "and I am weary from hunger"
#
# lak-	see-
# -ed-om	-PFV-1SG
# aha	this.m
# maṭraḥ
# -ī	-F
# ē-r-om	come-PFV-1SG
# .
# "I saw this place and wished to eat in it."
#
# ū	and
# hassaʕ	now
# ama	I
# bēn	between
# xast	hand
# -ē-r-ki	-PL-2SG.OBL-ABL
# .
# "and I am between thy hands.""
#
# ama	I
# kunt	COP.1SG/2SG
# bidd-ī	want-1SG
# qumn-	eat-
# -am	-1SG
# ehnē
# -na	-1PL
# .
# "He stayed , left the ox ten days"
#
# t-ōr	give.PFV-2SG
# man-	leave-
# -ī-r-a	-VITR-PFV-3SG.M
# hnon	there
# ʕašart
# iyyām	days
# .
# "it became as big as a camel"
#
# ē-r-a	come-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# abu	Abu
# ḥasan	Hasan
# .
# "Then came to him Abu Ḥasan"
#
# t-ōr	give.PFV-2SG
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# kē	what
# -
# -h-r-a	-VITR-PFV-3SG.M
# ?
# "the ox said "what is the matter?""
#
# abu	Abu
# ḥasan	Hasan
# š-	speak-
# -ird-a	-PFV-3SG.M
# :
# "Abu Ḥasan said,"
#
# nimer	Nimr
# man-	leave-
# -d-os-ir	-PFV-3SG-2SG
# aha	this.m
# maṭraḥ
# -ma	-LOC
# ,
# ū	and
# atu	you.SG
# nṣuḥh-
# -ok	-2SG
# ,
# ""The panther has left thee in this place till thou become fat , and aferwards"
#
# aw-	come-
# -ar-i	-3SG-PRES
# nimer	Nimr
# mar-	kill-
# -ar-r-i	-3SG-2SG-PRES
# daf-
# -r-ēs-m-a	-PFV-2PL-1SG-REM
# "she will strike thee with her paw"
#
# atu	you.SG
# mar-	kill-
# -š-ēk	-SUBJ-2SG
# ū	and
# nimer	Nimr
# qumn-	eat-
# -ar-r-i	-3SG-2SG-PRES
# .
# "thou wilt die and she will eat thee."
#
# sin	hear
# la	in.order.to/no
# aw-	come-
# -ar	-3SG
# ab
# -ur-ke	-2SG.OBL-BEN
# nimer	Nimr
# ,
# "If the panther comes to thee , redden thy eye upon her"
#
# atu	you.SG
# fumn-	hit-
# -ē-s	-PL-3SG/-2SG-3SG
# qrūn
# -ē-r-ma	-PL-2SG.OBL-LOC
# .
# "and strike her with your horn (to kill her)""
#
# ga-r-a	go-PFV-3SG.M
# abu	Abu
# ḥasan	Hasan
# nimir	Nimr
# -ke	-BEN
# ,
# "Abu Ḥasan betook himself , went to the panther , said"
#
# man-	leave-
# -d-or	-PFV-2SG
# tōr-as
# hay	this
# -ma	-LOC
# ḥašīš	grass
# -ma	-LOC
# ,
# ""Thou hast left the ox in the spring-grass;"
#
# dža	go
# xarrif-
# -h-ōš-ī	-VITR-SUBJ-2SG
# wāšī-s	SOC-1SG
# "go , let me see [thee] speak with him.""
#
# nimer	Nimr
# š-	speak-
# -ird-a	-PFV-3SG.M
# kēkē	how/why
# -ki	-ABL
# e-
# -h-r-a	-VITR-PFV-3SG.M
# ?
# "Said she "what has happened?""
#
# t-ōr	give.PFV-2SG
# e-
# -h-r-a	-VITR-PFV-3SG.M
# nāṣiḥ
# -i	-F/PRED.SG
# ,
# "Said Abu Ḥasan "The ox has become fat,"
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# t-ōr	give.PFV-2SG
# bidd-o	want-3SG.M
# m-	die-
# -ar-ir	-3SG-2SG
# .
# "so that if he sees you he will want to kill you""
#
# xul-
# -d-a	-PFV-3SG.M
# nimer	Nimr
# tōr-as-ke
# ,
# "The panther went down to the ox,"
#
# qaddima-
# -h-r-a	-VITR-PFV-3SG.M
# t-ōr	give.PFV-2SG
# ,
# "the ox thrust his horn (into the ground)"
#
# nṭaḥked-
# -os	-2PL
# qrūn
# -ē-s-ma	-PL-3SG.OBL-LOC
# .
# "and struck him"
#
# d-	give-
# -ird-os-is	-PFV-3SG-3SG
# la	in.order.to/no
# di	two
# šaqf
# -a	-M
# .
# "and split him into two pieces."
#
# gēna	again
# nimer	Nimr
# gaz-	bite-
# -id-os-is	-PFV-3SG-3SG
# "The panther struck him also and split him." 'bit him'
#
# din-
# -ē-san	-2SG-3PL
# m-	die-
# -r-e	-PFV-3PL
# ,
# t-ōr	give.PFV-2SG
# ū	and
# nimer	Nimr
# .
# "The two betook themselves and died , the ox and the panther."
#
# ē-r-a	come-PFV-3SG.M
# abu	Abu
# ḥasan	Hasan
# qē-	eat-
# -r-a	-PFV-3SG.M
# dīn-
# -ē-san	-2SG-3PL
# .
# "Abu Ḥasan arose from there , went to eat the two."
#
# nan-	bring-
# -d-a	-PFV-3SG.M
# bāy	wife
# -is	-3SG.OBL
# ū	and
# putr	son
# -ē-s	-PL-3SG/-2SG-3SG
# ,
# "He called his wife and children,"
#
# qē-	eat-
# -r-e	-PFV-3PL
# wāšī-s	SOC-1SG
# .
# "they ate with him."
#
# man-	leave-
# -ī-r-e	-VITR-PFV-3PL
# min	from
# dīn	religion/two
# -an-ki	-OBL.PL-ABL
# xa-
# -r-e	-PFV-3PL
# bass	but/only
# .
# "[until] there remained nothing of the two but bones."
#
# abu	Abu
# ḥasan	Hasan
# "abu ḥasan"
#
# nadi-
# -k-ed-a	-VTR-PFV-3SG.M
# qarāib-
# -ē-s	-PL-3SG/-2SG-3SG
# qē-	eat-
# -r-e	-PFV-3PL
# xa
# -ran	-2PL
# .
# "called his people (to eat the bones)"
#
# abu	Abu
# ḥasan	Hasan
# naw-	search-
# -r-a	-PFV-3SG.M
# ū	and
# nan-	bring-
# -d-a	-PFV-3SG.M
# farw
# -ak	-INDEF
# .
# "Abu Ḥasan searched , and saw a piece of fur/sheepskin coat"
#
# tird-	put-
# -os	-2PL
# ktāf
# -ē-s-ka	-PL-3SG.OBL-DAT
# .
# "and put the coat on his shoulders."
#
# nig-	enter-
# -r-a	-PFV-3SG.M
# mġār-
# -ē-m-a	-2SG-1SG-REM
# ,
# "He entered a cave,"
#
# lak-	see-
# -id-a	-PFV-3SG.M
# b-	fear-
# -ar-is	-3SG-3SG
# nimir	Nimr
# -ki	-ABL
# ,
# "saw the brother of the panther in the cave."
#
# nimer	Nimr
# par-	take-
# -d-os-is	-PFV-3SG-3SG
# ū	and
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# ,
# "The panther took him and saidː"
#
# abu	Abu
# ḥasan	Hasan
# kēkē	how/why
# mar-	kill-
# -d-or	-PFV-2SG
# b-	fear-
# -ar-im	-3SG-1SG
# ?
# ""Abu Ḥasan , why hast thou slain my brother?""
#
# ama	I
# mišš	NEG
# t-ōr-i	give.PFV-2SG-PRES
# .
# ""I am not the ox" (said by Abu Ḥasan)"
#
# atu	you.SG
# šbiq-
# -k-ed-or	-VTR-PFV-2SG
# bēnī
# -san	-3PL
# .
# ""It is he who roused the quarrel" (said by Abu Ḥasan)"
#
# nimer	Nimr
# lak-	see-
# -ed-a	-PFV-3SG.M
# farwē
# li	REL
# ktāfēs-
# -k-ēk	-VTR-2SG
# ,
# "The panther saw the sheepskin coat which was on his shoulder."
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# abu	Abu
# ḥasan	Hasan
# -
# -k-ar	-VTR-3SG
# ama	I
# -ke	-BEN
# gēna	again
# farw
# -ak	-INDEF
# zayy	like
# ēr
# -ak-i	-INDEF-PRED
# "Abu Ḥasan , Wilt though make for me one like that?"" 'like this on e'
#
# abu	Abu
# ḥasan	Hasan
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# ṭayyib
# ama	I
# nan-	bring-
# -am-i	-1SG-PRES
# ab
# -ur-ke	-2SG.OBL-BEN
# "Abu Ḥasan answered him "I will make it"
#
# nan	bring
# ama	I
# -ke	-BEN
# arbaʕ	four
# xurfān
# ,
# "fetch me four good sheep,"
#
# mar-	kill-
# -ē-san	-2SG-3PL
# ,
# "kill them"
#
# ū	and
# ama	I
# kar-	do-
# -am-i	-1SG-PRES
# ab
# -ur-ke	-2SG.OBL-BEN
# min	from
# farw
# -an-ki	-OBL.PL-ABL
# kabbūd	coat
# -ak	-INDEF
# .
# "(so) that I may make for thee a sheepskin coat.""
#
# nimer	Nimr
# nan-	bring-
# -d-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# arbaʕ	four
# xurfān
# ,
# "The panther betook himself , brought four sheep to him."
#
# qē-	eat-
# -r-a	-PFV-3SG.M
# māsy-
# -o-san	-2SG-3PL
# ,
# "He ate the flesh"
#
# ū	and
# t-	put-
# -ird-a	-PFV-3SG.M
# žild-
# -o-san	-2SG-3PL
# "and cast the skins"
#
# šał-
# -as-m-a	-2PL-1SG-REM
# .
# "in a pit"
#
# ē-r-a	come-PFV-3SG.M
# nimer	Nimr
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# kate-ta/
# kate-t
# -i	-F/PRED.SG
# balṭ
# -a	-M
# -y-a	-F-OBL.F
# abu	Abu
# ḥasan	Hasan
# ?
# "The panther came to him and said "Where is the coat , Abu Ḥasan?""
#
# xissa-
# -h-r-ēk	-VITR-PFV-PRES.3SG.M
# gēna	again
# dbīḥ
# -a	-M
# .
# "He said " there lacks another sheep""
#
# nimer	Nimr
# nan-	bring-
# -d-a	-PFV-3SG.M
# gēna	again
# dbīḥ
# -ak	-INDEF
# abu	Abu
# ḥasan	Hasan
# -as-ke	-OBL.M-BEN
# .
# "The panther brought him a sheep"
#
# abu	Abu
# ḥasan	Hasan
# mar-	kill-
# -d-os-is	-PFV-3SG-3SG
# ,
# "Abu Ḥasan killed it,"
#
# qē-	eat-
# -r-a	-PFV-3SG.M
# māsy-
# -as	-OBL.M/2PL
# ,
# "ate it"
#
# pandži	he/she
# ū	and
# putr	son
# -ē-s	-PL-3SG/-2SG-3SG
# ,
# "he and his children."
#
# ū	and
# k-	prepare-
# -urd-a	-PFV-3SG.M
# džild-
# -as	-OBL.M/2PL
# šał-
# -as-m-a	-2PL-1SG-REM
# .
# "and cast the skin into a pit."
#
# nimer	Nimr
# ē-r-a	come-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# ,
# "The panther came to him"
#
# kate-
# -ta	-DAT
# bal
# -ta	-DAT
# -y-a	-F-OBL.F
# abu	Abu
# ḥasan	Hasan
# ?
# "he said , "where is the coat , Abu Ḥasan?""
#
# stann-
# -h-ōš-ī	-VITR-SUBJ-2SG
# ama	I
# -ke	-BEN
# hnēna	here
# ū	and
# ama	I
# hessaʕ	now
# nan-	bring-
# -am-s-i	-1SG-3SG-PRES
# ab
# -ur-ke	-2SG.OBL-BEN
# .
# "He said "stay till I bring it""
#
# abu	Abu
# ḥasan	Hasan
# nas-	escape-
# -r-a	-PFV-3SG.M
# ,
# "Abu Ḥasan fled" 'chased him'
#
# nimer	Nimr
# ras-
# -r-os-is	-PFV-3SG-3SG
# "the panther followed him"
#
# nig-	enter-
# -r-e	-PFV-3PL
# mandž	inside
# -is-ma	-3SG.OBL-LOC
# mġār
# -ēk-i	-PRED.SG.M-PRED
# "He betook himself and went , he enters a cave"
#
# mīn-	hold-
# -d-os-is	-PFV-3SG-3SG
# min	from
# danab	tail
# -is-ki	-3SG.OBL-ABL
# "He took him by his tail;"
#
# abu	Abu
# ḥasan	Hasan
# falit-
# -k-ad-a	-VTR-3PL-REM
# ḥāl
# -is	-3SG.OBL
# min	from
# nimir	Nimr
# -ki	-ABL
# ū	and
# nas-	escape-
# -r-a	-PFV-3SG.M
# "Abu Ḥasan pulled himself (and escaped),"
#
# man-	leave-
# -ī-r-a	-VITR-PFV-3SG.M
# min	from
# ġēr
# danab	tail
# .
# "his tail was cut in the paw of the panther . Abu Ḥasan rose from there and remained tailless."
#
# hassaʕ	now
# atu	you.SG
# min	from
# ġēr
# danab	tail
# -i	-F/PRED.SG
# ,
# "The panther said to him , "Thou art tailless , Abu Ḥasan,"
#
# ū	and
# ama	I
# iza	if
# la-
# -k-am-r-i	-1SG-2SG-PRES
# džan-	know-
# -am-r-i	-1SG-2SG-PRES
# .
# "I will know thee.""
#
# abu	Abu
# ḥasan	Hasan
# ga-r-a	go-PFV-3SG.M
# min	from
# hnona
# ,
# "Abu Ḥasan went from there,"
#
# nimer	Nimr
# gēna	again
# ga-r-a	go-PFV-3SG.M
# min	from
# hnon	there
# .
# "the panther departed."
#
# ga-r-a	go-PFV-3SG.M
# la	in.order.to/no
# karem
# -i	-F/PRED.SG
# mindžīs
# ʕineb
# -i	-F/PRED.SG
# .
# "Hent to a vineyard , (ate grapes) from it."
#
# qē-	eat-
# -r-a	-PFV-3SG.M
# ʕineb
# .
# "ate grapes"
#
# nadi-
# -k-ad-a	-VTR-3PL-REM
# ū	and
# giš	all
# ahal-
# -os	-2PL
# ē-r-e	come-PFV-3PL
# .
# "He gave a shout (and) all of his people came."
#
# aw-	come-
# -as	-OBL.M/2PL
# qumn-	eat-
# -as	-OBL.M/2PL
# ʕineb
# .
# "(he said) "Let us eat grapes""
#
# ē-r-a	come-PFV-3SG.M
# karam
# -ka	-DAT
# ,
# "he made them descend into the vineyard."
#
# waqt	time
# -ma	-LOC
# itme	you.PL
# qās
# -i	-F/PRED.SG
# ama	I
# bidd-ī	want-1SG
# ban-	tie/shut-
# -am	-1SG
# danab-
# -ē-ran	-2SG-2PL
# .
# "he said "I will not suffer you to eat unless I bind your tails""
#
# abu	Abu
# ḥasan	Hasan
# ban-	tie/shut-
# -d-
# -o-san	-2SG-3PL
# "Abu Ḥasan bound them"
#
# ū	and
# ē-r-a	come-PFV-3SG.M
# ḥār
# -is-ke	-3SG.OBL-BEN
# ,
# "and came the watchman."
#
# wašwišked-
# -os	-2PL
# kan	ear
# -is-ma	-3SG.OBL-LOC
# ,
# "He shouted in his ear"
#
# ḥār
# -is	-3SG.OBL
# tuxxkod-
# -o-san	-2SG-3PL
# ,
# "The watchman rose from there , shot them with a gun"
#
# ū	and
# pēn-	take.out-
# -d-a	-PFV-3SG.M
# giš	all
# danab-
# -ē-san	-2SG-3PL
# .
# "and all their tails were plucked out."
#
# abu	Abu
# ḥasan	Hasan
# ga-r-a	go-PFV-3SG.M
# nimir	Nimr
# -ke	-BEN
# ,
# "Abu Ḥasan betook himself and went to the panther."
#
# nimir	Nimr
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# ama	I
# mīn-	hold-
# -am-r-i	-1SG-2SG-PRES
# -y-a	-F-OBL.F
# abu	Abu
# ḥasan	Hasan
# ,
# "He said "I will seize thee , Abu Ḥasan.""
#
# kēkē	how/why
# karwās
# -ir	-2SG.OBL
# ?
# "He said "Fellow , what dost tthou with me?""
#
# atu	you.SG
# qē-	eat-
# -r-or	-PFV-2SG
# xurfān-
# -an	-1PL
# qē-	eat-
# -r-or-san	-PFV-2SG-3PL
# ,
# "He said "thou has taken the sheep and eaten them"
#
# na	NEG
# ka-
# -d-or	-PFV-2SG
# ama	I
# -ke	-BEN
# balṭ
# -a	-M
# "and dist not make the sheepskin coat for me""
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# mišš	NEG
# ama	I
# -k	-2SG
# "he said "It is not I""
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# :
# atu	you.SG
# -
# -h-r-or-i	-VITR-PFV-2SG-PRES
# .
# "He said "It is thee""
#
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# kān	who/which/was
# -i	-F/PRED.SG
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab
# -ur-ke	-2SG.OBL-BEN
# inn-i	COMP-1SG
# ama	I
# -k	-2SG
# ?
# "He said "Who told thee that it was I?""
#
# ama	I
# š-	speak-
# -ind-om	-PFV-1SG
# ab
# -ur-ke	-2SG.OBL-BEN
# danab	tail
# -ir	-2SG.OBL
# .
# "he said "I cut off thy tail""
#
# giš	all
# qarāib-
# -ē-m	-2SG-1SG
# nhe’	there.is.not
# ab-san-ke	for-3PL-BEN
# danab	tail
# -e	-PL
# .
# "He said "All my people , all my near relations , are tailless""
#
# dža	go
# nadi-
# -k-ē-san	-2SG-3PL
# !
# "He said "Let me see , call them""
#
# abu	Abu
# ḥasan	Hasan
# nadiked-
# -o-san	-2SG-3PL
# "Abu Ḥasan shouted to them,"
#
# ū	and
# gištane	all
# -san	-3PL
# nhe’	there.is.not
# ab-san-ke	for-3PL-BEN
# danab	tail
# -e	-PL
# .
# "and they all came , the panther saw that they were all tailless."
#
# nimer	Nimr
# -ma	-LOC
# dž-	go-
# -and-a	-3PL-REM
# kān-ik	who-PRED.SG
# mindžī
# -san	-3PL
# illi	REL
# qēy-	eat-
# -r-a	-PFV-3SG.M
# xurfān-
# -an	-1PL
# .
# "he did not know which was the one who had eaten the sheep"
#
# abu	Abu
# ḥasan	Hasan
# iʕzim-
# -k-ad-a	-VTR-3PL-REM
# nimr	Nimr
# -ī	-F
# .
# "Abu Ḥasan betook himself and invited the panther"
#
# abu	Abu
# ḥasan	Hasan
# t-	put-
# -ird-a	-PFV-3SG.M
# bsāṭ-
# -ēk	-PRED.SG.M/2SG
# šāł
# -as-ka	-OBL.M-DAT
# .
# "Abu Ḥasan put a carpet on the mouth of the well"
#
# ū	and
# č-
# -ird-a	-PFV-3SG.M
# nimir	Nimr
# -ki	-ABL
# wēšt
# -ī	-F
# bṣāṭē
# -ka	-DAT
# .
# "and caused the panther to sit on it"
#
# ila-hu
# nimer	Nimr
# kw-	throw-
# -ir-a	-PFV-3SG.M
# šāł-
# -as-m-a	-2PL-1SG-REM
# .
# "and hefell into the middle of the well."
#
# nimer	Nimr
# št-	rise/stand-
# -ird-a	-PFV-3SG.M
# "The panther came from there"
#
# ū	and
# nuṭṭa-
# -h-r-a	-VITR-PFV-3SG.M
# ū	and
# kil-	exit/descend-
# -d-a	-PFV-3SG.M
# bara	outside
# ,
# "leapt from the well,"
#
# mīn-	hold-
# -d-a	-PFV-3SG.M
# abu	Abu
# ḥasan-
# -as	-OBL.M/2PL
# k-	prepare-
# -urd-os-is	-PFV-3SG-3SG
# šāłās
# -ma	-LOC
# .
# "siezed Abu Ḥasan and put him in the well."
#
# din-
# -ē-san	-2SG-3PL
# kānu	COP.3PL
# šāłasm
# -ēn-i	-PRED.PL-PRED
# .
# "The two were in the well."
#
# baʕd	after
# di	two
# dīs	day
# nimer	Nimr
# bkara-	hungry-
# -h-r-a	-VITR-PFV-3SG.M
# ,
# "In two days the panther died of hunger"
#
# abu	Abu
# ḥasan	Hasan
# qēy-	eat-
# -r-a	-PFV-3SG.M
# nimr	Nimr
# -ī	-F
# šāł-
# -as-m-a	-2PL-1SG-REM
# .
# "Abu Ḥasan ate the panther in the well."
#
# ge-
# -r-e	-PFV-3PL
# džuwr-ēn-i
# kn-	sell-
# -ad	-3PL
# šmary	chicken
# -ēn-i	-PRED.PL-PRED
# "There were women going to sell chickens."
#
# sall-
# -ē-san	-2SG-3PL
# kānu	COP.3PL
# bard-ēn-i
# ,
# "Their baskets were full"
#
# lak-	see-
# -ed-a	-PFV-3SG.M
# šał-
# -as	-OBL.M/2PL
# ,
# "They saw that well."
#
# e-
# -h-r-a	-VITR-PFV-3SG.M
# bara	outside
# arat	night
# -i	-F/PRED.SG
# "The sun set on them."
#
# sit-e	sleep.PFV-3PL
# ʕind	at/among
# šāl
# -as-ki	-OBL.M-ABL
# "They slept by the well."
#
# k-	prepare-
# -urd-e	-PFV-3PL
# šmary-	chicken
# -an	-1PL
# mandž	inside
# -is-ma	-3SG.OBL-LOC
# šāł
# -as-ki	-OBL.M-ABL
# "They lowered the chickend into the well."
#
# ʕašan	because
# šū-	sleep-
# -š-ad	-SUBJ-3PL
# šāł-
# -as-m-a	-2PL-1SG-REM
# "They made them sleep in the well that night"
#
# abu	Abu
# ḥasan	Hasan
# qē-	eat-
# -r-a	-PFV-3SG.M
# giš	all
# šmary-	chicken
# -an	-1PL
# "Abu Ḥasan did not leave a single chicken of them."
#
# sabaḥtan	in.the.morning
# džuwr-e
# kšal-	pull-
# -d-e	-PFV-3PL
# sallē
# -y	-1SG
# ,
# nhe’	there.is.not
# ,
# fāḍi
# -ni	-PRED.PL
# .
# "In the morning the women raised the basket from the well." 'they took out the basket , Ar sall e'
#
# abu	Abu
# ḥasan	Hasan
# sit-a	sleep.PFV-3SG.M
# mandž	inside
# -is-ma	-3SG.OBL-LOC
# sall
# -ēk-i	-PRED.SG.M-PRED
# .
# "he/Abu Ḥasan was sleeping in the basketǃ"
#
# lamma	when
# isḥa-
# -h-r-a	-VITR-PFV-3SG.M
# nas-	escape-
# -r-a	-PFV-3SG.M
# ,
# "When he got up outside , he fled"
#
# džuwr-e
# row-	cry-
# -r-e	-PFV-3PL
# ,
# "Those women wept"
#
# ū	and
# gar-	go-
# -ī-r-e	-VITR-PFV-3PL
# kuryas
# -an-ka	-OBL.PL-DAT
# .
# "and returned , departed to their houses."
#
# abu	Abu
# ḥasan	Hasan
# š-	speak-
# -ird-a	-PFV-3SG.M
# :
# "Abu Ḥasan betook himself , he said"
#
# ama	I
# bidd-ī	want-1SG
# -
# -h-ōš-am	-VITR-SUBJ-1SG
# hāž
# ū	and
# baṭṭil-	stop-
# -h-ōš-am	-VITR-SUBJ-1SG
# qumn-	eat-
# -am	-1SG
# ū	and
# qaft-	steal-
# -am	-1SG
# .
# ""I want to go to the haj and cease from sin""
#
# lak-	see-
# -ed-a	-PFV-3SG.M
# qrar	Bedouin
# -a	-M
# ū	and
# qul-
# -d-ēk	-PFV-PRES.3SG.M
# dawāy	camel
# -ka	-DAT
# bidd-ō	want-3SG.M
# dža	go
# hižžhōšār
# .
# "There was a bedawi riding a camel , going to the haj."
#
# mīn-	hold-
# -d-a	-PFV-3SG.M
# danab	tail
# -is	-3SG.OBL
# dawāy	camel
# -ki	-ABL
# ,
# "Abu Ḥasan seized the tail of the camel."
#
# qrar	Bedouin
# -a	-M
# kahind-
# -ar-a	-3SG-REM
# lah-	see-
# -ed-os-is	-PFV-3SG-3SG
# mīn-	hold-
# -d-ēk	-PFV-PRES.3SG.M
# danab	tail
# -is	-3SG.OBL
# dawāy	camel
# -ki	-ABL
# "The bedawi looked and saw him seizing the tail of the camel."
#
# qrar	Bedouin
# -a	-M
# pēn-	take.out-
# -d-a	-PFV-3SG.M
# sēf-
# -as	-OBL.M/2PL
# ,
# "The bedawi betook himself , seized the sword,"
#
# fē-r-a	hit-PFV-3SG.M
# abu	Abu
# ḥasan	Hasan
# -as-ke	-OBL.M-BEN
# ila-hu
# qtaʕka-
# -d-ēk	-PFV-PRES.3SG.M
# danab	tail
# -is	-3SG.OBL
# dawāy	camel
# -ki	-ABL
# .
# "And struck Abu Ḥasan thus , and cut the tail of his camel."
#
# abu	Abu
# ḥasan	Hasan
# nas-	escape-
# -r-a	-PFV-3SG.M
# .
# "Abu Ḥasan betook himself and returned."
#
# lak-	see-
# -ed-a	-PFV-3SG.M
# ʕaṣfur
# -i	-F/PRED.SG
# sit-ik	sleep.PFV-3SG.F.PRES
# pandži	he/she
# ū	and
# putr	son
# -ē-s	-PL-3SG/-2SG-3SG
# .
# "He saw a bird on the way sleeping on its young."
#
# ē-r-a	come-PFV-3SG.M
# qumn-	eat-
# -ar	-3SG
# putr	son
# -ē-s	-PL-3SG/-2SG-3SG
# ʕaṣf
# -ur-ki	-2SG.OBL-ABL
# .
# "he came from there to eat its chilren"
#
# na	NEG
# qumna	eat
# putr-	son
# -ē-m	-2SG-1SG
# !
# "Don't eat my childrenǃ"
#
# abu	Abu
# ḥasan	Hasan
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# :
# xizaw-
# -ē-m	-2SG-1SG
# !
# "Abu Ḥasan said "Make me laugh"
#
# ʕaṣfur
# -
# -š-ar-i	-SUBJ-3SG-PRES
# ab-us-ke	for-3SG-BEN
# keh
# -ni	-PRED.PL
# ?
# "She said "At what?""
#
# ašti	there.is
# maṭ	somebody
# -ēn-i	-PRED.PL-PRED
# qṭuf-
# -k-ad-i	-VTR-3PL-PRES
# min	from
# zaraʕ
# -ki	-ABL
# "He said "At those harvesters.""
#
# ʕasf-
# -ur-a	-PFV-3SG.M
# š-	speak-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# ṭayyib
# ,
# wēšt
# -ī	-F
# ,
# stannohōš
# -i	-F/PRED.SG
# !
# "She said "stay where you are""
#
# ʕaṣfur
# -a	-M
# ṭīra-
# -h-r-i	-VITR-PFV-3SG.F
# mind-
# -ird-i	-PFV-3SG.F
# siry	head
# -is-ka	-3SG.OBL-DAT
# ikak	one.F
# min	from
# illi	REL
# qṭuf-
# -k-ad-i	-VTR-3PL-PRES
# .
# "The bird came , sat on the head of one of the men."
#
# ila-hu
# ē-r-ēk	come-PFV-PRES.3SG.M
# kažž
# -ak-i	-INDEF-PRED
# hēy
# -ma	-LOC
# sēf-
# -as-m-a	-2PL-1SG-REM
# bidd-o	want-3SG.M
# šn-
# -ar	-3SG
# siry	head
# -is	-3SG.OBL
# ʕaṣf
# -ur-ki	-2SG.OBL-ABL
# .
# "One man came from there , he came to strike the bird with the sickle;"
#
# š-	speak-
# -ind-a	-PFV-3SG.M
# siry-	head
# -os	-2PL
# kažž
# -as-ki	-OBL.M-ABL
# ,
# "he cut off the head of the man."
#
# abu	Abu
# ḥasan	Hasan
# xaz-
# -r-a	-PFV-3SG.M
# bsuṭa-
# -h-r-a	-VITR-PFV-3SG.M
# "Abu Ḥasan laughed , he was contented."
#
# kān	who/which/was
# bidd-o	want-3SG.M
# qumn-	eat-
# -ar	-3SG
# putr	son
# -ē-s	-PL-3SG/-2SG-3SG
# ʕaṣfur
# -ēk-i	-PRED.SG.M-PRED
# .
# "He rushed on the children of the bird , he went to eat them."
#
# č-
# -ird-a	-PFV-3SG.M
# ab-us-ke	for-3SG-BEN
# karw-
# -as-ir	-2PL-2SG
# kē	what
# bidd-ak	want-2SG.M
# ?
# "She said "What do you want?""
#
# ama	I
# tirsala-	thirsty-
# -h-r-om-i	-VITR-PFV-1SG-PRES
# ,
# bidd-ī	want-1SG
# py-	drink-
# -am	-1SG
# .
# "he said "I am thirsty , I want to drink"
#
# ama	I
# bidd-ī	want-1SG
# py-	drink-
# -am	-1SG
# illi	REL
# mīnd-
# -os	-2PL
# ihi	this.F
# kadždž	non.Dom
# -i	-F/PRED.SG
# .
# "that which a woman is carrying in a jug of water.""
#
# ʕaṣfur
# mind-
# -ird-a	-PFV-3SG.M
# agir	in.front.of
# kadždž	non.Dom
# -ak-i	-INDEF-PRED
# ,
# "The bird stepped in front of the woman."
#
# kadždž	non.Dom
# -i	-F/PRED.SG
# xlaw-	take.out-
# -ird-i	-PFV-3SG.F
# gar
# -y-a	-F-OBL.F
# ,
# "The woman set down her jugs there,"
#
# ū	and
# ga-r-i	go-PFV-3SG.F
# biddh
# -a	-M
# mīn-	hold-
# -ar	-3SG
# ʕaṣfur
# -ī	-F
# ,
# "and ran to take the bird."
#
# ē-r-a	come-PFV-3SG.M
# abu	Abu
# ḥasan	Hasan
# pī-	drink-
# -r-a	-PFV-3SG.M
# giš	all
# pan
# -y-a	-F-OBL.F
# .
# "Abu Ḥasan came , drank all her water."

# %% [markdown]
# ## Step 4: Formatting for Interlinear Glossing
#
# This step reformats the glossed text into a standard three-line interlinear glossing format.
#
# The input file (`output_texts/glossed.txt`) contains one word per line, optionally followed by a gloss separated by a tab.
# Each sentence block is separated by an empty line and may include a free translation enclosed in quotation marks (e.g., `'` or `"`).
#
# For each block, the script outputs:
#
# 1. A segmented sentence
# 2. A gloss line
# 3. A free translation line
#
# If a gloss is missing:
# - `*` is inserted for general words
# - `-*` is inserted if the word begins with a hyphen (e.g., for clitics)
#
# After formatting, an additional cleaning step is applied to remove formatting artifacts such as:
# - Extra spaces before punctuation (e.g., `' , '` → `','`)
# - Double asterisks (`**`) for punctuation marks
# - Redundant hyphenation (e.g., `- -` → `-`)
#
# Example:
# - nan ama-ke arbaʕ xurfān,
# - bring I-BEN four *
# - "fetch me four good sheep,"

# %%
def format_glossing(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
        sentence = []
        gloss = []
        translation = None

        def write_entry():
            if sentence and gloss:
                outfile.write(' '.join(sentence) + '\n')
                outfile.write(' '.join(gloss) + '\n')
                if translation:
                    outfile.write(translation + '\n')
                outfile.write('\n')

        for line in infile:
            line = line.strip()

            # When an empty line is encountered, output the accumulated lines as one entry
            if not line:
                write_entry()
                sentence = []
                gloss = []
                translation = None
                continue

            # Store the line if it is a translation line
            if line.startswith(("'", '"', "‘", "“")) and line.endswith(("'", '"', "’", "”")):
                translation = line
                continue

            # Include punctuation in the main text
            if line in ['.', '?', '!', ':', ',', ';']:
                sentence.append(line)
                continue

            parts = line.split('\t')

            if len(parts) == 2:
                sentence.append(parts[0])
                gloss.append(parts[1])
            elif len(parts) == 1:
                sentence.append(parts[0])
                gloss.append('-*' if parts[0].startswith('-') else '*')

        # Output the last entry even if there is no empty line at the end of the file
        write_entry()


# Specify input and output file paths
input_file = 'output_texts/glossed.txt'
output_file = 'output_texts/formatted_glossing.txt'

# Process the file
format_glossing(input_file, output_file)

print("Data reformatted and saved to", output_file)
# Out:
# Data reformatted and saved to output_texts/formatted_glossing.txt

# %%
# Define replacements
replacements = {
    ' ,': ',',
    ' .': '.',
    ' !': '!',
    ' ?': '?',
    ' :': ':',
    ' ;': ';',
    ' **': '',
    '- -': '-',
    ' -': '-',
    '- ': '-'
}

# Load the file
input_file = "output_texts/formatted_glossing.txt"  # Adjust path if necessary
output_file = "output_texts/cleaned_formatted_glossing.txt"

# Read content
with open(input_file, "r", encoding="utf-8") as file:
    content = file.read()

# Apply replacements
for old, new in replacements.items():
    content = content.replace(old, new)

# Save cleaned content
with open(output_file, "w", encoding="utf-8") as file:
    file.write(content)

print(f"Cleaning complete. Saved as {output_file}")
# Out:
# Cleaning complete. Saved as output_texts/cleaned_formatted_glossing.txt
